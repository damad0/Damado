# %%
import random
dibujo= [
    '''
        +---+
        |   |
            |
            |
            |
            |
            ============''', 
            '''
        +---+
        |   |
        O   |
            |
            |
            |
            ============''', 
            '''
        +---+
        |   |
        O   |
        |   |
            |
            |
            ============''', 
            '''
        +---+
        |   |
        O   |
        |\  |
            |
            |
            ============''',
            '''
        +---+
        |   |
        O   |
       /|\  |
            |
            |
            ============''',
            '''
        +---+
        |   |
        O   |
       /|\  |
         \  |
            |
            ============''',
            '''
        +---+
        |   |
        O   |
       /|\  |
       / \  |
            |FAILED
            ============'''
]

oracion='''
pera chocolate tomate platano pan agujero trasnocharse llave tren avellana sanguijuela huevo


'''

def sacandoPalabra():
    palabra=oracion.split()
    n= random.randint(0,len(palabra)-1)
    return palabra[n]
def main():
    palabra=sacandoPalabra()
    lpalabra=[]
    l2palabra=[]
    if palabra=="pera":
              print("Blanca por dentro,\nverde por fuera.\nSi no sabes,\nespera.")
    if palabra=="chocolate":
      print("Choco entre dos paredes\nlate mi corazón.\nQuien no sepa mi nombre\nes un cabezón.")
    if palabra=="tomate":
      print("Un señor gordito,\nmuy coloradito,\nno toma café,\nsiempre toma té")
    if palabra=="platano":
      print("Oro parece, plata no es.\nAbran las cortinas,\ny verán lo que es.")
    if palabra=="pan":
      print("Lo come Pancracio,\nestá en el champán;\nsi piensas despacio\nsabrás que es el...")
    if palabra=="agujero":
      print("¿Qué cosa es que cuanto más le quitas más grande es?")
    if palabra=="trasnocharse":
      print("¿Qué es lo que se hace de noche, que no se puede hacer de día?")
    if palabra=="llave":
      print("No muerde ni ladra, pero tiene dientes y la casa guarda. ¿Qué es?")
    if palabra=="tren":
      print("Naomi nos envía la siguiente adivinanza:\nLargo largero, Martín Caballero, sin patas ni manos y corre ligero")
    if palabra=="avellana":
      print("¿cuál es el ave que tiene la panza llana?")
    if palabra=="sanguijuela":
      print("¿cuál es el bicho sin hueso ni espina?")
    if palabra=="huevo":
      print("Entre unas paredes blancas hay una rosa amarilla, que se puede presentar al mismo Rey de Castilla.")
    for i in palabra:
        lpalabra.append(i)
        l2palabra.append('__')
    #print(palabra)
    #print(','.join(l2palabra))
    contaDibujo=0
    print(dibujo[contaDibujo])
    print(','.join(l2palabra))
    while True:
        llave=False       
        entrada=input('\nIngrese Letra= ')
        conta=-1
        if palabra=="pera":
              print("\nBlanca por dentro,\nverde por fuera.\nSi no sabes,\nespera.")
        if palabra=="chocolate":
          print("\nChoco entre dos paredes\nlate mi corazón.\nQuien no sepa mi nombre\nes un cabezón.")
        if palabra=="tomate":
          print("\nUn señor gordito,\nmuy coloradito,\nno toma café,\nsiempre toma té")
        if palabra=="platano":
          print("Oro parece, plata no es.\nAbran las cortinas,\ny verán lo que es.")
        if palabra=="pan":
          print("Lo come Pancracio,\nestá en el champán;\nsi piensas despacio\nsabrás que es el...")
        if palabra=="agujero":
          print("\n¿Qué cosa es que cuanto más le quitas más grande es?")
        if palabra=="trasnocharse":
          print("\n¿Qué es lo que se hace de noche, que no se puede hacer de día?")
        if palabra=="llave":
          print("\nNo muerde ni ladra, pero tiene dientes y la casa guarda. ¿Qué es?")
        if palabra=="tren":
          print("\nNaomi nos envía la siguiente adivinanza:\nLargo largero, Martín Caballero, sin patas ni manos y corre ligero")
        if palabra=="avellana":
          print("\n¿cuál es el ave que tiene la panza llana?")
        if palabra=="sanguijuela":
          print("¿cuál es el bicho sin hueso ni espina?")
        if palabra=="huevo":
          print("\nEntre unas paredes blancas hay una rosa amarilla, que se puede presentar al mismo Rey de Castilla.")

        for i in palabra:
            conta+=1
            if entrada==i:
                l2palabra[conta]=entrada
                llave=True
        if lpalabra==l2palabra:
            print('\n¡¡Felicitaciones\nGanaste!!')
            break
        if contaDibujo>=5 and llave != True:
            print(dibujo[6])
            print('\nPerdiste la palabra es: ', ''.join(lpalabra))
            break
        elif llave==False:
            contaDibujo+=1
        print(dibujo[contaDibujo])
        print(','.join(l2palabra))
main()
# Out:
# ¿Qué cosa es que cuanto más le quitas más grande es?
#
#         +---+
#         |   |
#             |
#             |
#             |
#             |
# ...
# __,__,__,__,__,__,__
#
# Ingrese Letra= l
#
# ¿Qué cosa es que cuanto más le quitas más grande es?
#
#         +---+
#         |   |
#         O   |
#             |
#             |
#             |
# ...
# __,__,__,__,__,__,__
#
# Ingrese Letra= a
#
# ¿Qué cosa es que cuanto más le quitas más grande es?
#
#         +---+
#         |   |
#         O   |
#             |
#             |
#             |
# ...
# a,__,__,__,__,__,__
#
# Ingrese Letra= g
#
# ¿Qué cosa es que cuanto más le quitas más grande es?
#
#         +---+
#         |   |
#         O   |
#             |
#             |
#             |
# ...
# a,g,__,__,__,__,__
#
# Ingrese Letra= u
#
# ¿Qué cosa es que cuanto más le quitas más grande es?
#
#         +---+
#         |   |
#         O   |
#             |
#             |
#             |
# ...
# a,g,u,__,__,__,__
#
# Ingrese Letra= j
#
# ...
